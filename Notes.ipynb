# %% [markdown]
# # Day11
# BlackJack Capstone project
# [Example](https://appbrewery.github.io/python-day11-demo/)

# %% [markdown]
# ## Requirements
# - The card deck is stable throughout (with unlimited site) - no removal
# - The Jack, Queen and Kings also represented as 10
# - No Joker
# - Ace counts as 11 or 1
# - The cards in the list have equal probabilit of being drawn
# - Computer needs to draw if less then 17

# %%
import blackjack
blackjack.main()
# Out:
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _' |/ __| |/ / |/ _' |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# '-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       '------'                           |__/
#
# Your current hand: [10, 10], Total: 20.
# Opponent's current hand: [6], Total: 6
# Your final hand: [10, 10], Total: 20.
# Opponent's final hand: [6, 9, 8], Total: 23
# Opponent went over. You win. 😃
# The program exits. Thank you.
